# %%
#Program 1
import math

class ComplexNumber(object): 
    def __init__(self, real, compl): 
        self.real = real 
        self.compl = compl
        pass
    def __str__(self):
        if (self.compl == 0):
            return "{0:.2f}".format(self.real) +''
        if (self.real == 0):
            return "{0:.2f}".format(self.compl) +'i'
        if (self.compl > 0):
            return "{0:.2f}".format(self.real) +' + '+ "{0:.2f}".format(self.compl) +'i' 
        return "{0:.2f}".format(self.real) +' - '+ "{0:.2f}".format(abs(self.compl)) +'i' 
    def __add__(x, y):
        return ComplexNumber(x.real+y.real, x.compl+y.compl)
    def __sub__(x, y):
        return ComplexNumber(x.real-y.real, x.compl-y.compl)
    def __mul__(x, y):
        return ComplexNumber(x.real*y.real - x.compl*y.compl, x.compl*y.real + x.real*y.compl)
    def __truediv__(x, y):
        return ComplexNumber((x.real*y.real + x.compl*y.compl) / (y.real*y.real + y.compl*y.compl), 
                             (x.compl*y.real - x.real*y.compl) / (y.real*y.real + y.compl*y.compl))
    def mod(self):
        return ComplexNumber(math.sqrt(self.real*self.real + self.compl*self.compl), 0)
    
help = list(map(float, input().split(' ')))   
x = ComplexNumber(help[0], help[1])    
help = list(map(float, input().split(' ')))   
y = ComplexNumber(help[0], help[1])    

print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x.mod())
print(y.mod())

# %%
#PROGRAM 2
import math
class point():
    pass
class line():
    pass

A = point()
A.x,A.y,A.z = [float(i) for i in input().split()]
B = point()
B.x,B.y,B.z = [float(i) for i in input().split()]
C = point()
C.x,C.y,C.z = [float(i) for i in input().split()]
D = point()
D.x,D.y,D.z = [float(i) for i in input().split()]

AB = line()
AB.x,AB.y,AB.z = B.x-A.x,B.y-A.y,B.z-A.z
BC = line()
BC.x,BC.y,BC.z = C.x-B.x,C.y-B.y,C.z-B.z
CD = line()
CD.x,CD.y,CD.z = D.x-C.x,D.y-C.y,D.z-C.z

X = line()
X.x,X.y,X.z = AB.y*BC.z-AB.z*BC.y, AB.x*BC.z-AB.z*BC.x, AB.x*BC.y-AB.y*BC.x
Y = line()
Y.x,Y.y,Y.z = BC.y*CD.z-BC.z*CD.y, BC.x*CD.z-BC.z*CD.x, BC.x*CD.y-BC.y*CD.x

cosphi = (X.x*Y.x+X.y*Y.y+X.z*Y.z)/math.sqrt(X.x**2+X.y**2+X.z**2)/math.sqrt(Y.x**2+Y.y**2+Y.z**2)

phi = math.acos(cosphi)

print("{:.2f}".format(math.degrees(phi)))

# %%
class Data(object):
def __init__ (self, a):
    self.a = a

def __lt__ (self, other):
    return int(self.a[i]) < int(other.a[i])

def __gt__ (self, other):
    return other.__lt__(self)

def __eq__ (self, other):
    return int(self.a[i]) == int(other.a[i])

def __ne__ (self, other):
    return not self.__eq__(other)


s = input()
nm = s.split(' ')
allData = []
for x in range(0, int(nm[0])):
s = input();
d = s.split(' ')
allData.append(Data(d))

s = input()

i = int(s);
allData = sorted(allData)

for d in allData:
s = ''
for y in range(0, int(nm[1])):
s = s + d.a[y]+' '
print(s)

# %%
#Program if else
n = int(input())
if(n%2!=0):
    print("Weird")
elif(n%2==0 and n>=2 and n<=5):
    print("Not Weird")
elif(n%2==0 and n>=6 and n<=20):
    print("Weird")
elif(n%2==0 and n>20):
    print("Not Weird")

# %%
#Write a function
def is_leap(year):
    leap = False
    if(year%4!=0):
        leap = False
    elif(year%4==0 and year%100==0 and year%400!=0):
        leap = False
    else:
        leap = True
    return leap
year = int(input())
print(is_leap(year))

# %%
#Merge the Tools
s = input()
k = int(input())

i = 0
map, to_print = {}, ""
while i < len(s):
    if i % k == 0 and i != 0:
        print(to_print)
        map, to_print = {}, ""
    if s[i] not in map.keys():
        map[s[i]] = 0
        to_print += s[i]
    i += 1
print(to_print)

# %%
#The Minion Game
input_string =input().strip()
list1=list(input_string)
string = ""
stuart = 0
kevin = 0

for i in range (0,len(list1)):
    if list1[i] in ['a','e','i','o','u','A','E','I','O','U'] :
        kevin = kevin +  len(list1) - (i+1) + 1
    else : 
        stuart = stuart + len(list1) - (i+1) + 1
if kevin > stuart :
    print ("Kevin", kevin)
elif kevin == stuart :
    print ("Draw")
else :

    print ("Stuart", stuart)

# %%
#REDUCED FUNCTION
n,m = map(int,rinput().split())
lst = []
for i in range(n):
    lst.append(map(int,input().split()))
k = int(raw_input())    
print(map(lambda x: " ".join(map(str, x)), sorted(lst, key = lambda x: x[k])))

# %%
from functools import reduce
from fractions import gcd

n = int(input())
rationals = []
for i in range(n):
    rationals.append(list(map(int, input().split())))
s = [list(a) for a in zip(*rationals)]
print(s)
k = [reduce(lambda x, y: x*y, s[i]) for i in range(2)]
c = reduce(gcd, k)
for i in range(2):
    k[i] //= c
print(*k)

# %%
#BOOK STORE
class BookStore:
    title=""
    author=""
    publisher=""
    price=0
    
    def _init_(self,t,a,p,pr):
        self.__title=t
        self.__author=a
        self.__publisher=p
        self.__price=pr
        global c
        c=c+1
    def BookInfo(self):
        print("Title: "+self.__title)
        print("Author: "+self.__author)
        print("Publisher: "+self.__publisher)
        print("Price: Rs. ",self.__price)
c=0
lis=[]
while True:
    f=int(input("Enter -1 to end: "))
    if(f==-1):
        break;
        print("Total Books: ",c)
    else:
        t=input("Enter Title: ")
        a=input("Enter Author: ")
        p=input("Enter Publisher: ")
        pr=int(input("Enter Price: "))
        obj=BookStore(t,a,p,pr)
        lis.append(obj)
print("-------------------------------------")
n=int(input("Access Entry?: "))
obj1=lis[n]
print("-------------------------------------")
obj1.BookInfo()

# %%
import sys

stdin = sys.stdin

n = int(stdin.readline())
for i in range(2*n-1):
    d = n-1-abs(n-1-i)
    for j in range(4*n-3):
        if j % 2 == 0 and abs((j-(2*n-2))//2) <= d:
            sys.stdout.write(chr(97+n-1-(d-abs((j-(2*n-2))//2))))
        else:
            sys.stdout.write("-")
    sys.stdout.write("\n")

# %%
#rangoli
n=int(input())
for i in range(n-1,-1,-1):
    for j in range(i):
        print(end="--")
    for j in range(n-1,i,-1):
        print(chr(j+97),end="-")
    for j in range(i,n):
        if j != n-1:
            print(chr(j+97),end="-")
        else:
            print(chr(j+97),end="")
    for j in range(2*i):
        print(end="-")
    print()
for i in range(1,n):
    for j in range(i):
        print(end="--")
    for j in range(n-1,i,-1):
        print(chr(j+97),end="-")
    for j in range(i,n):
        if j != n-1:
            print(chr(j+97),end="-")
        else:
            print(chr(j+97),end="")
    for j in range(2*i):
        print(end="-")
    print()
# Out:
# 3
# ----c----
# --c-b-c--
# c-b-a-b-c
# --c-b-c--
# ----c----

# %%
#Apple and Orange
import sys


s,t = input().strip().split(' ')
s,t = [int(s),int(t)]
a,b = input().strip().split(' ')
a,b = [int(a),int(b)]
m,n = input().strip().split(' ')
m,n = [int(m),int(n)]
apple = [int(apple_temp) for apple_temp in input().strip().split(' ')]
orange = [int(orange_temp) for orange_temp in input().strip().split(' ')]

count = 0
for i in range(len(apple)):
    if (a+apple[i])>=s and (a+apple[i])<=t:
        count += 1
print(count)
count = 0
for i in range(len(orange)):
    if (b+orange[i])>=s and (b+orange[i])<=t:
        count += 1
print(count)
# Out:
# 7 11
# 5 15
# 3 2
# -2 2 1
# 5 -6
# 1
# 1

# %%
#Mini-Max Sum
a = input().strip().split(' ')
for i in range(0, len(a)):
    a[i] = int(a[i])
    
s = sum(a)
print(str(s - max(a)) + " " + str(s - min(a)))
# Out:
# 1 2 3 4 5
# 10 14

# %%
line = input().split(' ')
rows = int(line[0])
cols = int(line[1])

table = []

for i in range(rows):
    line = input().split(' ')
    table.append([int(x) for x in line])
    
sort_key = int(input())
table.sort(key = lambda x: x[sort_key])

for row in table:
    print(' '.join(str(x) for x in row))
# Out:
# 5 3
# 10 2 5
# 7 1 0
# 9 9 9
# 1 23 12
# 6 5 9
# 1
# 7 1 0
# 10 2 5
# 6 5 9
# 9 9 9
# 1 23 12
